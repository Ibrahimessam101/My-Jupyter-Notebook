# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Ibrahim Essam </b><br>
# Data Scientist

# %% [markdown]
# I am interested in data science because I have a passion for using data to draw meaningful conclusions about a company's growth, I appreciate when I can draw insight from data and help build actionable solutions.

# %% [markdown]
# ### The following code will display the result of 2 * 5

# %%
result = 2 * 5
print ("The result is" , result)
# Out:
# The result is 10

# %% [markdown]
# # Shopping List
#
# 1. Coffee
# 2. Tea
# 3. Milk
# 4. Cheese
# ***
# ***
#
# |Name|Age|ID|GPA|Job|
# |:---:|:---:|:---:|:---:|:---:|
# |Ahmed|25|1234|4|Data Scientist|
# |Sam|23|2314|3.1|Data Analyst|
# |Matt|30|2413|3.6|Data Engineer|
#
# ***
# ***
# [https://www.google.com/]
